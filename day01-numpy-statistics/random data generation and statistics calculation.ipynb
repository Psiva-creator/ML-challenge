# %%
#random data generation and statistics calculation
import numpy as np
data =np.random.default_rng(seed=42)
data=(data.integers(1,101,size=10))
print("DATA:",data)
#statistics
print("Mean:",np.mean(data))
print("Median:",np.median(data))
print("Standard Deviation:",np.std(data))
print("Range:",np.max(data)-np.min(data)    )
print("Variance:",np.var(data))
print("Minimum:",np.min(data))
print("Maximum:",np.max(data))
#indexes of maximum and minimum
print("Index of Minimum:",np.argmin(data))
print("Index of Maximum:",np.argmax(data))
# Out:
# DATA: [ 9 78 66 44 44 86  9 70 21 10]
# Mean: 43.7
# Median: 44.0
# Standard Deviation: 28.660251220113196
# Range: 77
# Variance: 821.4099999999999
# Minimum: 9
# Maximum: 86
# Index of Minimum: 0
# Index of Maximum: 5
